# %%
import pandas as pd

# %%
df1 = pd.read_csv("./cleaned Datasets/MetaData.csv")
df2 = pd.read_csv("./cleaned Datasets/ProductInfo.csv")

# %%
df1.head(2)
# Out:
#   product Id                                               name  \
# 0         P1  Gadson RO Solenoid Valve 24 VDC for Kent/AQUAG...
# 1         P2  Van Heusen Sport Men's Slim Shirt (VSSFWSLP299...
#
#      sub_category main_category  \
# 0  All Appliances    appliances
# 1   Men's Fashion        stores
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/21h-aU43wL...
# 1  https://m.media-amazon.com/images/I/91RVshFBEM...
#
#                                                 link  discount_price  \
# 0  https://www.amazon.in/Gadson-Solenoid-Valve-Aq...           150.0
# 1  https://www.amazon.in/Van-Heusen-Sport-Shirt-V...           619.0
#
#    actual_price  ratings  no_of_ratings
# 0         300.0      3.0            292
# 1        2299.0      4.0              5

# %%
df2.head(2)
# Out:
#                                                 name main_category  \
# 0  Gadson RO Solenoid Valve 24 VDC for Kent/AQUAG...    appliances
# 1  Van Heusen Sport Men's Slim Shirt (VSSFWSLP299...        stores
#
#      sub_category  ratings  no_of_ratings  discount_price  actual_price  \
# 0  All Appliances      3.0            292           150.0         300.0
# 1   Men's Fashion      4.0              5           619.0        2299.0
#
#   product Id  discount percentage Rating Bucket  Popularity Score  \
# 0         P1             50.00000       Average         17.040518
# 1         P2             73.07525          Good          7.167038
#
#    Value Score                                       cleaned_name  \
# 0     0.113603  gadson ro solenoid valve 24 vdc for kentaquaga...
# 1     0.011578  van heusen sport men's slim shirt (vssfwslp299...
#
#   cleaned_sub_category                                               tags
# ...

# %%
df1.columns
# Out:
# Index(['product Id', 'name', 'sub_category', 'main_category', 'image', 'link',
#        'discount_price', 'actual_price', 'ratings', 'no_of_ratings'],
#       dtype='object')

# %%
import requests

def check_image(url):
    try:
        response = requests.get(url, timeout=5)

        return response.status_code == 200

    except:
        return False

# %%
df1['sub_category'].value_counts()
# Out:
# sub_category
# Ethnic Wear                   16183
# Men's Fashion                 15267
# All Appliances                 8503
# Home Entertainment Systems     8503
# All Electronics                8076
# Headphones                     7842
# Car Accessories                1381
# Home Décor                     1205
# Name: count, dtype: int64
